# %% [markdown]
# ## Challenge 2 : apprentissage supervisé
#
# - Andrés Vázquez
# - Claire Yao
# - Thibaud Gerin-Roze
# - Ayoube Fathi
# - Bilal Guemes

# %%
# Importing some libraries that we'll use later
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.svm import SVR
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
# Here we get the files paths and make a list with the names of the columns we're gonna have 
path = 'HGS/'
directories = os.listdir(path)
columns = ['s'+str(i) for i in range(1,19)]
columns = ['instance','cost_solution'] + columns

# %%
# We open all the files of the data set and get a dataframe with more tha 14 million rows.
#So , we're going to make some feature selection. But first lets se that the dataset don't
#have null values and wird stuff.
dfs = [pd.read_csv(path + i +'/'+ j, sep=';',names = columns) for i in directories for j in os.listdir(path+i)]
df = pd.concat(dfs)
df.head()
# Out:
#          instance  cost_solution        s1        s2      s3      s4       s5  \
# 0  XML100_2213_16          12777  137.0910   98.5511  0.2196  0.3788  425.538
# 1  XML100_2213_16          12591   98.3619   42.7941  0.1051  0.0529  420.071
# 2  XML100_2213_16          12681  103.3510   49.7809  0.1003  0.0433  418.429
# 3  XML100_2213_16          12691  155.4840  107.5330  0.1944  0.2361  416.538
# 4  XML100_2213_16          12690  158.8430  105.3390  0.2202  0.2433  415.769
#
#         s6  s7       s8      s9     s10      s11     s12     s13     s14  \
# 0  112.713   0  340.769  0.3400  0.1727  484.615  0.2643  0.1321  0.0202
# 1  121.849   0  289.429  0.3198  0.1473  493.286  0.2930  0.1465  0.0364
# 2  115.255   0  304.429  0.3387  0.1202  531.857  0.3954  0.1977  0.2248
# 3  124.092   0  331.769  0.3420  0.1308  552.923  0.2619  0.1310  0.0121
# 4  125.099   0  328.077  0.3352  0.1371  550.000  0.2610  0.1305  0.0082
#
#        s15      s16     s17     s18
# 0  343.036  354.490  0.8213  5.1305
# 1  258.568  368.178  1.3015  4.3288
# 2  254.380  372.682  1.9949  3.8112
# 3  280.978  370.279  0.6057  3.9185
# 4  281.544  368.911  0.4615  3.9908

# %%
df.info(memory_usage='deep',show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14109514 entries, 0 to 117291
# Data columns (total 20 columns):
#  #   Column         Non-Null Count     Dtype
# ---  ------         --------------     -----
#  0   instance       14109514 non-null  object
#  1   cost_solution  14109514 non-null  int64
#  2   s1             14109514 non-null  float64
#  3   s2             14109514 non-null  float64
#  4   s3             14109514 non-null  float64
#  5   s4             14109514 non-null  float64
#  6   s5             14109514 non-null  float64
#  7   s6             14109514 non-null  float64
#  8   s7             14109514 non-null  int64
#  9   s8             14109514 non-null  float64
#  10  s9             14109514 non-null  float64
#  11  s10            14109514 non-null  float64
#  12  s11            14109514 non-null  float64
#  13  s12            14109514 non-null  float64
#  14  s13            14109514 non-null  float64
#  15  s14            14109514 non-null  float64
#  16  s15            14109514 non-null  float64
#  17  s16            14109514 non-null  float64
#  18  s17            14109514 non-null  float64
#  19  s18            14109514 non-null  float64
# dtypes: float64(17), int64(2), object(1)
# memory usage: 3.0 GB

# %% [markdown]
# Since the Non-Null count of all the columns is equal to the number of entries, we don't have missing values.

# %%
df.describe()
# Out:
#        cost_solution            s1            s2            s3            s4  \
# count   1.410951e+07  1.410951e+07  1.410951e+07  1.410951e+07  1.410951e+07
# mean    1.723776e+04  1.709193e+02  9.152957e+01  1.160378e-01  7.697894e-02
# std     5.029218e+03  4.938682e+01  2.857905e+01  6.445211e-02  5.376710e-02
#
#         s6       s8      s9     s10      s11     s12     s13     s14      s15  \
# 0  112.713  340.769  0.3400  0.1727  484.615  0.2643  0.1321  0.0202  343.036
# 1  121.849  289.429  0.3198  0.1473  493.286  0.2930  0.1465  0.0364  258.568
# 2  115.255  304.429  0.3387  0.1202  531.857  0.3954  0.1977  0.2248  254.380
# 3  124.092  331.769  0.3420  0.1308  552.923  0.2619  0.1310  0.0121  280.978
# 4  125.099  328.077  0.3352  0.1371  550.000  0.2610  0.1305  0.0082  281.544
#
#        s16     s17     s18
# 0  354.490  0.8213  5.1305
# 1  368.178  1.3015  4.3288
# 2  372.682  1.9949  3.8112
# 3  370.279  0.6057  3.9185
# 4  368.911  0.4615  3.9908

# %% [markdown]
# Now we are going to look for the correlations between the features, so we can drop some of the feautures. For example, if we have three feautures that have a correlation > 0.9 we're going to drop two and just keep the one that has the higher correlation with the target value.

# %%
#Let's compute the correlation matrix and find those feautures that are highly correlated
corr = df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap=plt.cm.CMRmap_r,annot=True)
plt.show()
# Out:
# /var/folders/_t/q7hcjcqn0g5dkr3kqqrlx4200000gn/T/ipykernel_13625/1117303614.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
#Now we are going to select the ones to drop
corr_features = {}
threshold = 0.9
#corr_matrix = df.corr()
for i in range(len(corr.columns)):
    for j in range(i):
        corr_i_j = abs(corr.iloc[i, j])
        if corr_i_j > threshold: 
            corr_features[(corr.columns[i],corr.columns[j])] = corr_i_j                   
corr_features
# Out:
# {('s5', 'cost_solution'): 0.936667473114434,
#  ('s8', 'cost_solution'): 0.9122556159051326,
#  ('s8', 's5'): 0.9550118980731472,
#  ('s11', 's5'): 0.9340366604469228,
#  ('s11', 's8'): 0.993298138831954,
#  ('s13', 's12'): 0.9999997739449461,
#  ('s14', 's12'): 0.9541319651511111,
#  ('s14', 's13'): 0.9541377493946464,
#  ('s15', 's6'): 0.9887835694252607}

# %% [markdown]
# From the highly correlated feautures, we are going to keep the colums s5, s6 and s12

# %%
df.drop(['s11','s8','s13','s14','s15'],axis=1,inplace=True)
df.head()
# Out:
#          instance  cost_solution        s1        s2      s3      s4       s5  \
# 0  XML100_2213_16          12777  137.0910   98.5511  0.2196  0.3788  425.538
# 1  XML100_2213_16          12591   98.3619   42.7941  0.1051  0.0529  420.071
# 2  XML100_2213_16          12681  103.3510   49.7809  0.1003  0.0433  418.429
# 3  XML100_2213_16          12691  155.4840  107.5330  0.1944  0.2361  416.538
# 4  XML100_2213_16          12690  158.8430  105.3390  0.2202  0.2433  415.769
#
#         s6      s9     s10     s12      s16     s17     s18
# 0  112.713  0.3400  0.1727  0.2643  354.490  0.8213  5.1305
# 1  121.849  0.3198  0.1473  0.2930  368.178  1.3015  4.3288
# 2  115.255  0.3387  0.1202  0.3954  372.682  1.9949  3.8112
# 3  124.092  0.3420  0.1308  0.2619  370.279  0.6057  3.9185
# 4  125.099  0.3352  0.1371  0.2610  368.911  0.4615  3.9908

# %% [markdown]
# So after deleting some feature that were highly correlated, we left with only 12 feautures. We can start to make some models with that kind of data.

# %%
"""
    Here we apply several times the function train_test_split, because we don't want just 
    to truncate the dataset. We are not ussing the whole dataset because is really big,
    but with the function train_test_split() we are going to get a representative sample
    of the whole dataset.
"""


X = df.drop(['instance', 'cost_solution'], axis=1)
y = df['cost_solution']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.9, random_state = 1)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.9, random_state = 1)
X_train, X_test1, y_train, y_test1 = train_test_split(X_train, y_train, test_size = 0.9, random_state = 1)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.2, random_state = 1)

# %%
X_train.shape
# Out:
# (11287, 12)

# %%
model = KNeighborsRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
#accuracy_score(y_test, model.predict(X_test))
model.score(X_test1,y_test1)
# Out:
# 0.9831184006361668

# %%
model2 = RandomForestRegressor(n_estimators = 10)
model2.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10)

# %%
model2.score(X_test,y_test)
# Out:
# 0.9991408224446958

# %%
model3 = DecisionTreeRegressor()
model3.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model3.score(X_test,y_test)
# Out:
# 0.9984004405127159

# %% [markdown]
# ### Making a classification problem

# %% [markdown]
# We are going to make a boolean variable depending on the cost of the solution. The cost of the solution has a maximum value of max = 27588, and a minimum value of min = 7766.
# So, we are going to take the mid value mid = (max + min)/2 = 17677
# Our threshold to say that a solution is a good solution is gona be 17677. So all solutions that have a cost <= 17677 are going to have a 1 in the new column, otherwise they're gonna have a 0

# %%
df['good_bad']= [1 if i <= 17677 else 0 for i in df.cost_solution ]

# %%
df
# Out:
#               instance  cost_solution        s1        s2      s3      s4  \
# 0       XML100_2213_16          12777  137.0910   98.5511  0.2196  0.3788
# 1       XML100_2213_16          12591   98.3619   42.7941  0.1051  0.0529
# 2       XML100_2213_16          12681  103.3510   49.7809  0.1003  0.0433
# 3       XML100_2213_16          12691  155.4840  107.5330  0.1944  0.2361
# 4       XML100_2213_16          12690  158.8430  105.3390  0.2202  0.2433
# ...                ...            ...       ...       ...     ...     ...
# 117287  XML100_3113_17          22654  170.7360   92.6274  0.0803  0.0811
# 117288  XML100_3113_17          22654  196.3670   93.4426  0.0828  0.0412
# 117289  XML100_3113_17          22654  184.5730  104.4960  0.0833  0.0444
# 117290  XML100_3113_17          22654  184.6250  103.5100  0.0778  0.0729
# 117291  XML100_3113_17          22654  183.7830   82.7013  0.0833  0.0555
#
#              s5       s6      s9     s10     s12      s16     s17     s18  \
# 0       425.538  112.713  0.3400  0.1727  0.2643  354.490  0.8213  5.1305
# 1       420.071  121.849  0.3198  0.1473  0.2930  368.178  1.3015  4.3288
# 2       418.429  115.255  0.3387  0.1202  0.3954  372.682  1.9949  3.8112
# 3       416.538  124.092  0.3420  0.1308  0.2619  370.279  0.6057  3.9185
# 4       415.769  125.099  0.3352  0.1371  0.2610  368.911  0.4615  3.9908
# ...         ...      ...     ...     ...     ...      ...     ...     ...
# 117287  878.917  313.289  0.3445  0.1133  0.3704  488.166  2.2111  4.0833
# 117288  869.833  316.599  0.3374  0.1075  0.3704  494.770  2.2111  3.9010
# 117289  876.917  270.053  0.3763  0.1093  0.2546  482.179  1.5456  3.7250
# 117290  870.500  331.680  0.3344  0.1204  0.3704  493.351  2.2111  4.7604
# 117291  875.917  332.568  0.3567  0.1092  0.3704  489.528  2.2111  3.8958
#
#         good_bad
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 117287         0
# 117288         0
# 117289         0
# 117290         0
# 117291         0
#
# [14109514 rows x 15 columns]

# %%
X = df.drop(['instance', 'cost_solution','good_bad'], axis=1)
y = df['good_bad']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.9, random_state = 1)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.9, random_state = 1)
X_train, X_test1, y_train, y_test1 = train_test_split(X_train, y_train, test_size = 0.9, random_state = 1)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.2, random_state = 1)

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
accuracy_score(y_test, model.predict(X_test))
# Out:
# 0.9748405386250886
